# %% [markdown]
# # Econ Simulator
#
# With the previous units simulatin forest fires and sugar economies, I was inspired to develop my own CA simulation to model modern-economies with more realism and precision than those previous labs.

# %% [markdown]
# Imports

# %%
# !pip install empiricaldist
from empiricaldist import Cdf, Pmf

import os
if not os.path.exists('utils.py'):
    # !wget https://raw.githubusercontent.com/AllenDowney/ThinkComplexity2/master/notebooks/utils.py
if not os.path.exists('Cell2D.py'):
    # !wget https://raw.githubusercontent.com/AllenDowney/ThinkComplexity2/master/notebooks/Cell2D.py


# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import random as rand
import uuid

from utils import decorate

from scipy.signal import correlate2d
from Cell2D import Cell2D, draw_array
from functools import reduce
import operator
import sys
from pprint import pprint
# Out:
# Collecting empiricaldist
#   Downloading empiricaldist-0.8.0.tar.gz (12 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from empiricaldist) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from empiricaldist) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from empiricaldist) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from empiricaldist) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->empiricaldist) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->empiricaldist) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->empiricaldist) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->empiricaldist) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->empiricaldist) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->empiricaldist) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->empiricaldist) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->empiricaldist) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->empiricaldist) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->empiricaldist) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->empiricaldist) (1.17.0)
# Building wheels for collected packages: empiricaldist
#   Building wheel for empiricaldist (pyproject.toml) ... done
#   Created wheel for empiricaldist: filename=empiricaldist-0.8.0-py3-none-any.whl size=12586 sha256=b3ff4863e6437e88da1e33491ca9ab2ed9c2804292a8a3968430894d08d1fe89
#   Stored in directory: /root/.cache/pip/wheels/ca/a9/1f/90c7a8a37ac37ff0fa0a27b2152f9b24be8910448ab93992f8
# Successfully built empiricaldist
# Installing collected packages: empiricaldist
# Successfully installed empiricaldist-0.8.0
# --2025-04-20 20:11:13--  https://raw.githubusercontent.com/AllenDowney/ThinkComplexity2/master/notebooks/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2645 (2.6K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   2.58K  --.-KB/s    in 0s
#
# 2025-04-20 20:11:13 (39.7 MB/s) - ‘utils.py’ saved [2645/2645]
#
# --2025-04-20 20:11:14--  https://raw.githubusercontent.com/AllenDowney/ThinkComplexity2/master/notebooks/Cell2D.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2628 (2.6K) [text/plain]
# Saving to: ‘Cell2D.py’
#
# Cell2D.py           100%[===================>]   2.57K  --.-KB/s    in 0s
#
# 2025-04-20 20:11:14 (27.6 MB/s) - ‘Cell2D.py’ saved [2628/2628]

# %% [markdown]
# Simulation class

# %%
MAX_AGENT_AGE = 100
# How much an agen't health decreases each tick
HEALTH_AGE_STEP = 0.0002
PROFESSIONS = ["research", "teaching", "farming", "building", "mining", "forestry", "business", "labour"]
# How likely the agent is to dropout of school based on how old it is
DROPOUT_CHANCE_PER_AGE = 0.0005
# The minimum age an agent must be before it drops out of school
MIN_DROPOUT_AGE = 6
# The learning rate for skills not related to the current profession, if no longer in school
NON_PROFESSION_LEARNING_RATE = 0.1
SCHOOL_LEARNING_RATE = 2
# How much better the agent is at their job based on their skill as a decaying rate - simulate decaying marginal ability
SKILL_JOB_ABILITY_RATE = 0.85
# Basic needs required to live (not required if still in school)
BASE_EXPENSES = 10_000
# Agents loose skill a small percent when they age
AGE_KNOWLEDGE_LOSS = 0.999
# Agents loose skill by an increasing amount with age
AGE_KNOWLEDGE_LOSS_AGE_MODIFIER = 0.0001
# How old the agent has to be before it can have kids
MIN_PARENT_AGE = 30
# Default chance of the agent wanting children
PARENT_CHANCE = 0.0005
# How demotivated the agent is from having children for each child it already has
ADDITIONAL_CHILD_DEMOTIVATION = PARENT_CHANCE * 20
# The minimum cost it takes to run a business per tick
MIN_BUSINESS_EXPENSE = 30_000
# The minimum employee salary
MIN_SALARY = 50_000
# The minimum percent of job postings to look through
MIN_JOB_SEARCHES = 5
# The minimum time an agent can be an employee before trying to transfer to a different business
MIN_EMPLOYMENT_TIME = 4
# How much a business makes per employee
PROFIT_PER_EMPLOYEE = 10_000

# %%
class EconSimulator(Cell2D):

  def __init__(self, n, start_agents_count):
    self.n = n

    self.create_agents(start_agents_count)
    self.society = Society()
    # Businesses mapped by their id
    self.businesses = {}
    self.history = History()

  def create_agents(self, start_agents_count):

    positions = [i for i in range(self.n)]
    rand.shuffle(positions)

    # Create agents with random starting wealth amounts
    self.agents = {}

    for i in positions[0:start_agents_count]:
      agent = Agent(i, 100_000)
      self.agents[agent.id] = agent

  def run(self):
    for i in range(self.n):
      self.step(i)

  def step(self, tick):

    taxes_paid = 0

    # Track who is working what jobs

    professions = create_work_ledger()

    for agent in self.agents.values():
      if agent.profession == None:
        continue

      professions[agent.profession] += 1

    # Try to start businesses

    for agent in self.agents.values():
      if agent.can_start_business() == False:
        continue

      # Start a business

      business = Business(agent.id)
      self.businesses[business.id] = business
      agent.business_id = business.id

      agent.wealth -= MIN_BUSINESS_EXPENSE
      business.assets += MIN_BUSINESS_EXPENSE

      print(f"Starting a new business with id {business.id}")

    # Either go to school or try to work

    for agent in self.agents.values():
      if agent.in_school:
        agent.school(self.society)
        continue

      income = agent.try_work(self.society, self.businesses)
      # If they made money, tax them
      if income:
        tax = income * self.society.tax_rate

        agent.wealth -= tax
        taxes_paid += tax

    # Run businesses

    agent_ids_set = set(self.agents.keys())

    business_ids = list(self.businesses.keys())
    for business_id in business_ids:
      business = self.businesses[business_id]

      # If the owner is dead, delete the business
      if not business.owner_id in agent_ids_set:
        del self.businesses[business.id]
        continue

      owner = self.agents[business.owner_id]

      if owner.run_business(business, self.agents):
        continue

      # The business has failed, liquidate the business

      owner.wealth += business.assets * 0.1

      del self.businesses[business.id]
      owner.business_id = None

      print(f"Deleted business with id {business.id}")

    # Age and expenses

    agent_keys = list(self.agents.keys())
    for agent_id in agent_keys:
      agent = self.agents[agent_id]

      # If the agent died from old age
      if agent.step_age() == False:
        del self.agents[agent.id]
        continue

      # If we are not in school, we have to pay for expenses
      if agent.in_school == False:
        # If we died due to not having money to pay for expenses
        if agent.expenses() == False:
          del self.agents[agent.id]
      # If we are in school, society pays for basic needs
      else:
        self.society.funds -= BASE_EXPENSES

    # Children

    agent_keys = list(self.agents.keys())
    for agent_id in agent_keys:
      agent = self.agents[agent_id]

      if agent.wants_kids() == False:
        continue

      inheritance = agent.wealth / 2

      new_agent = Agent(agent.pos, inheritance)
      self.agents[new_agent.id] = new_agent

      agent.wealth -= inheritance
      agent.children += 1

      print(f"Created child")

    # Society updates

    self.society.funds += taxes_paid
    self.society.update_desires()
    self.society.update_tax_rate()

    # Extra History updates
    print(f"recording history; remaining agents: {len(self.agents)} tick: {tick}")

    self.history.tax_income.append(self.society.tax_rate)
    self.history.gov_funds.append(self.society.funds)

    self.history.agent_count.append(len(self.agents))

    total_assets = reduce(lambda sum, agent_id: sum + self.agents[agent_id].wealth, self.agents, 0)
    self.history.total_assets.append(total_assets)
    self.history.avg_assets.append(total_assets / (len(self.agents) + sys.float_info.epsilon))

    agent_skills = map(lambda agent_id: reduce(operator.add, self.agents[agent_id].skills.values()), self.agents)

    total_skill = reduce(lambda sum, skills_sum: sum + skills_sum, list(agent_skills), 0)
    avg_skill = total_skill / (len(self.agents) + sys.float_info.epsilon)
    self.history.avg_skill.append(avg_skill)

    self.history.businesses_count.append(len(self.businesses))

    in_school_count = reduce(lambda sum, agent_id: sum + 1 if self.agents[agent_id].in_school else 0, self.agents, 0)
    print(f"in school {in_school_count}")
    self.history.in_school.append(in_school_count)
    # Workers are those who are not in school or running businesses
    self.history.at_work.append(len(self.agents) - in_school_count - len(self.businesses))

  def draw(self):
    """Draws the cells."""
    draw_array(self.array, cmap='YlOrRd', vmax=9, origin='lower')

    # draw the agents
    xs, ys = self.get_coords()
    self.points = plt.plot(xs, ys, '.', color='red')[0]

def get_coords(self):
    """Gets the coordinates of the agents.

    Transforms from (row, col) to (x, y).

    returns: tuple of sequences, (xs, ys)
    """
    agents = self.agents
    rows, cols = np.transpose([agent.pos for agent in agents])
    xs = cols + 0.5
    ys = rows + 0.5
    return xs, ys

class Society():
  def __init__(self):
    # How much each skill is socially desired
    self.desired_skills = create_work_ledger()
    # How much unspent tax money has accumilated (can be negative as a deficit)
    self.funds = 0
    # How much to tax income-earners on
    self.tax_rate = 0.1

  def update_desires(self):
    """Randomly change desired skills to simulate changes in culture and material needs"""
    for skill in self.desired_skills:
      self.desired_skills[skill] = min(max(self.desired_skills[skill] + rand.uniform(-1, 1), 0.1), 2)

  def update_tax_rate(self):
    if self.funds <= 0:
      self.tax_rate += 0.0005
    else: self.tax_rate -= 0.0005

    self.tax_rate = max(min(self.tax_rate, 0.5), 0)

class Business():
  def __init__(self, owner_id):
    self.id = uuid.uuid4()
    self.assets = 0
    self.owner_id = owner_id
    self.employee_ids = []
    self.salaries = create_work_ledger_random()

class History():
  def __init__(self):
    self.tax_income = []
    self.gov_funds = []
    self.agent_count = []
    self.total_assets = []
    self.avg_assets = []
    self.avg_skill = []
    self.businesses_count = []
    self.in_school = []
    self.at_work = []

  def graph(self):
    """
    Graph all of the below-specified graph subjects of history
    """
    graph_subjects = {
        "tax rate": self.tax_income,
        "gov' funds": self.gov_funds,
        "agent count": self.agent_count,
        "total assets": self.total_assets,
        "average assets": self.avg_assets,
        "average skill": self.avg_skill,
        "business count": self.businesses_count,
        "in school": self.in_school,
        "at work": self.at_work,
    }
    graph_keys = list(graph_subjects.keys())
    subjects_count = len(graph_subjects)

    fig, axs = plt.subplots(subjects_count, 1, figsize=(8, 4 * subjects_count))

    for index in range(subjects_count):

      graph_title = graph_keys[index]

      graph_data = graph_subjects[graph_title]

      axs[index].plot(range(len(graph_data)), graph_data)
      axs[index].set_title(graph_title)

# %% [markdown]
# Agent Components and Utilities

# %%
# Motivations from 0-1
class Motivations():
  def __init__(self):
    self.financial = 0
    self.social = 0

# Can't use a class since we need to index the keys dynamically
# Skills 0-1
def create_work_ledger():
  return {
      "research": 0,
      "teaching": 0,
      "farming": 0,
      "building": 0,
      "mining": 0,
      "forestry": 0,
      "business": 0,
      "labour": 0,
  }

def create_work_ledger_random():
  ledger = create_work_ledger()

  for skill in ledger:
      ledger[skill] = rand.random()

  return ledger

# %% [markdown]
# Agent

# %%
class Agent():
  def __init__(self, pos, inherit_wealth, inherited_skills = create_work_ledger_random()):
    self.id = uuid.uuid4()
    self.health_death_chance = 0
    self.age = 0
    self.wealth = inherit_wealth
    self.children = 0
    # The id of the business the agent owns
    self.business_id = None
    self.pos = pos
    self.in_school = True
    # The id of the business that employs the agent
    self.employment_id = None
    self.employment_time = 0
    self.profession = None
    self.motivations = Motivations()
    self.inherit_skills(inherited_skills)

  def inherit_skills(self, inherited_skills):
    """
    Inherit skills from the parent based relative to their highest skill

    The idea is to simulate learning from parents and tedning to want to do the work they do
    """

    # Give the agent random skill
    self.skills = create_work_ledger_random()

    highest_inherited = max(inherited_skills.values())

    # Then inherit the parent's
    for skill in inherited_skills:
      self.skills[skill] += inherited_skills[skill] / highest_inherited

  def step_age(self) -> False:
    """Returns: bool: if the agent survived the aging step"""

    # Chance to die based on age-related factors
    if rand.random() < self.health_death_chance: return False

    # How motivated the agent is to live - simulates eating healthier, putting on sunscreen, etc.
    motivation = self.motivations.financial + self.motivations.social

    health_chance_delta = HEALTH_AGE_STEP - (HEALTH_AGE_STEP * motivation)
    self.health_death_chance += health_chance_delta

    # Loose skill knowledge faster as the agent gets older

    for skill in self.skills:
      skill_delta = AGE_KNOWLEDGE_LOSS + (AGE_KNOWLEDGE_LOSS_AGE_MODIFIER * self.age)
      self.skills[skill] *= skill_delta

    self.age += 1
    return True

  def school(self, society):
    """Have the agent go to school"""
    # Will get better at skills based on:
    # parent's profession, modified by social
    # society's desires, modified by social
    # financial prospect, modified by financial

    # Could use reduce but am lazy

    total_skill = 0

    for skill in self.skills:
      total_skill += self.skills[skill]

    avg_skill = total_skill / len(self.skills)

    # Increase all skills based on motivation
    # Increase skills that we are already good at - specialization

    for skill in self.skills:
      # Above-average skill increase to simulate specialization
      distance = min(max((self.skills[skill] - avg_skill), 0), 0.1)

      desire = self.motivations.social * (1 + society.desired_skills[skill]) + self.motivations.financial + distance
      skill_delta = desire * SCHOOL_LEARNING_RATE
      self.skills[skill] += skill_delta

    # Can't drop out of school until we get old enough

    if self.age < MIN_DROPOUT_AGE:
      return

    # Chance to drop out of school, encouraged by lack of motivation

    motivation = self.motivations.financial + self.motivations.social
    dropout_chance = (1 + motivation) - (DROPOUT_CHANCE_PER_AGE * self.age)

    if rand.random() > dropout_chance:
      self.in_school = False
      print(f"agent dropping out of school: {self.id}")
      return

  def try_work(self, society, businesses) -> float | None:
    """
    Try to perform a job if we meet conditions, such as not owning a business and having/finding a job to do
    """
    # If we are a business owner, stop

    business_owner_ids = set(map(lambda b_id: businesses[b_id].owner_id, businesses))
    if self.id in business_owner_ids:
      return

    # If we are registered as being employed and the employer (business) exists, work the job
    if self.employment_id and businesses[self.employment_id]:
      if self.try_update_job(businesses):
        return

      return self.job()

    # If we don't have an employer we need to find a job

    if self.choose_and_find_job(businesses):
      return self.job(society)

  def choose_and_find_job(self, businesses) -> bool:
    """
    Finds and becomes an employee of the best job the agent is motivated to find

    Returns: Wether or not a job was found
    """
    job = self.find_job(businesses)
    if job == None:
      return False

    # Assign the employee and business to each other

    business = businesses[job[2]]
    skill = job[0]
    self.choose_job(business, skill)

    return True

  def try_update_job(self, businesses) -> bool:
    """
    So long as we pass the requirements, try to pick a job with better pay
    """

    # If we haven't been employed at the current job for long enough, stop
    if self.employment_time < MIN_EMPLOYMENT_TIME:
      return False

    current_business = businesses[self.business_id]
    new_job = self.find_job()

    # If the new job pays worse, stop
    if new_job[1] <= self.salary:
      return False

    return True

  def choose_job(self, business, skill):
    business.employee_ids.append(self.id)
    self.business_id = business.id
    self.employment_time = 0
    self.profession = skill

  def find_job(self, businesses):
    """
    Find the best job of a list of potential jobs

    Returns: The skill, salary, and business id of the job
    """
    # Special care for those who have high business skill

    # Find a job from a local business
    # The further away the business, the more expensive it is to move there

    # Construct a list of jobs

    # Each business is considered to be offering one job
    jobs_count = len(businesses)
    # List of (skill, salary, business_id)
    jobs = []

    for business_id in businesses:
      business = businesses[business_id]

      for skill in business.salaries:
        salary = business.salaries[skill]
        jobs.append((skill, salary, business.id))

    if len(jobs) == 0:
      return None

    # Based on motivation, search through some of the jobs and choose the best paying one

    rand.shuffle(jobs)

    job = max(jobs, key=lambda job: job[1] * (1 + self.skills[job[0]]))
    return job

  def job(self, society) -> float:
    """
    Have the agent work its job

    Returns: how much the the job paid
    """
    # Will make money based on:
    # societal demand for the job
    # skill in the job

    # Work the job

    job_ability = self.skills[self.profession] ** SKILL_JOB_ABILITY_RATE
    pay = MIN_SALARY * job_ability * society.desired_skills[self.profession]

    self.wealth += pay

    # Improve the agent's skill based on their motivations

    skill_delta = self.motivations.financial + self.motivations.social
    self.skills[self.profession] += skill_delta

    # Slightly increase other skills based on motivation
    # Simulate general knowledge gain with age

    for skill in self.skills:
      skill_delta = self.motivations.financial + self.motivations.social * NON_PROFESSION_LEARNING_RATE
      self.skills[skill] += skill_delta

    return pay

  def expenses(self) -> False:
    """
    Simulate food, shelter, water, etc. costs, as well as conditional and correlary luxury-goods expenses

    Returns: If the agent survived paying their expenses
    """
    # Basic costs like food, water, housing, etc.
    self.wealth -= BASE_EXPENSES

    # If we could not afford basic expenses, we die
    if self.wealth < 0:
      print(f"Insufficient funds to pay base expenses {self.id}")
      return False

    # Additional expenses on "luxury goods" based on motivations

    net_motivation = self.motivations.social - self.motivations.financial
    if net_motivation > 0:
      # Will only spend a portion of wealth
      additional_expenses = (self.wealth / 8) * net_motivation
      self.wealth -= additional_expenses

    return True

  def wants_kids(self) -> bool:
    """Returns: If the agent wants to have a child"""

    if self.age < MIN_PARENT_AGE: return False
    if self.in_school: return False

    # Simulate the financial disincentive to have a child vs social desire to
    net_motivation = max(self.motivations.social - self.motivations.financial, 0.1)

    # Default chance to have a child based on age, take away chance based on additional children
    child_chance = (PARENT_CHANCE * self.age) - (ADDITIONAL_CHILD_DEMOTIVATION * self.children)
    return rand.random() < child_chance

  def run_business(self, business, agents) -> bool:
    """Returns: If the business is still opperational"""

    # Expenses and assets conversion

    expenses = MIN_BUSINESS_EXPENSE
    self.wealth -= expenses
    # Some of the expenses are converted into liquid assets
    business.assets += expenses * 0.1

    # Profit

    profit = 0

    for employee_id in business.employee_ids:
      try:
        employee = agents[employee_id]
      except:
        continue

      profit += PROFIT_PER_EMPLOYEE * (1 + self.motivations.financial - self.motivations.social)
    print(f"business profit {profit}")
    self.wealth += profit

    if self.wealth < 0: return False
    return True

  def can_start_business(self) -> bool:
    """
    See if we meet the conditions to start a business
    """
    if self.in_school:
      return False
    if self.business_id:
      return False

    # Make sure we have sufficient wealth to run a business for a bit
    if self.wealth < MIN_BUSINESS_EXPENSE * 3:
      return False

    # Make sure business is one of our best skills
    total_skill = 0
    for skill_val in self.skills.values():
      total_skill += skill_val
    avg_skill = total_skill / len(self.skills)

    if self.skills["business"] <= avg_skill:
      return False
    print(f"sufficient skill to start business")
    return True

# %% [markdown]
# # Simulation Proper
#
# Now for running the simulation and showing the results

# %%
def test_short():
  simulation = EconSimulator(50, 100)
  simulation.run()

  simulation.history.graph()

def test_medium():
  simulation = EconSimulator(200, 100)
  simulation.run()

  simulation.history.graph()

def test_long():
  simulation = EconSimulator(600, 100)
  simulation.run()

  simulation.history.graph()

def test_extra_long():
  simulation = EconSimulator(2000, 100)
  simulation.run()

  simulation.history.graph()

def main():
  test_extra_long()

main()
# Out:
# Streaming output truncated to the last 5000 lines.
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 1790000
# business profit 0
# business profit 310000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 920000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# recording history; remaining agents: 744 tick: 1128
# in school 120
# sufficient skill to start business
# Starting a new business with id b555930c-42c9-498f-a65a-8a38d2d69b8d
# sufficient skill to start business
# Starting a new business with id b6816f8a-fbe8-4157-94b2-f7ca005055a2
# agent dropping out of school: 8f3f7735-61b5-4539-ba5c-1acb193cea67
# agent dropping out of school: d88bfced-f075-4a21-b9e3-5746cf25946e
# agent dropping out of school: c1d7d23e-9801-41f0-b6fc-291c31d6b656
# agent dropping out of school: b6a50800-45a8-4553-9aa8-af543430189b
# agent dropping out of school: fb0bad3f-4d3a-4e5c-963a-a5508042394a
# agent dropping out of school: 88c7b319-e6a5-48e5-8cff-ee823dff675b
# business profit 240000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit

# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 1180000
# business profit 0
# business profit 0
# business profit 2400000
# business profit 90000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 2200000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 70000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# recording history; remaining agents: 736 tick: 1141
# in school 131
# sufficient skill to start business
# Starting a new business with id d813caef-e351-44aa-957f-e2d3baa5e514
# sufficient skill to start business
# Starting a new business with id 94c14563-043f-4066-9360-599d8a992a50
# sufficient skill to start business
# Starting a new business with id 08c9b385-7fd4-4c06-93a2-853006adedff
# sufficient skill to start business
# Starting a new business with id 37b77371-d9c9-4521-9b82-80472fac8414
# sufficient skill to start business
# Starting a new business with id 320ab673-7750-4fc3-828a-284b05db04a0
# sufficient skill to start business
# Starting a new business with id e4481a3a-1276-4298-b1b6-305b00aaf763
# sufficient skill to start business
# Starting a new business with id 7374e7e8-9098-49d3-943b-e8c6c4f865c0
# agent dropping out of school: fb6ab965-f3cd-4c38-b4db-21ad13f1e3fc
# agent dropping out of school: 3ebddde2-0401-4917-9bd9-91042eaabd91
# agent dropping out of school: 397ff6d6-4972-4cbb-a36e-8f2972b39811
# agent dropping out of school: d2292dc4-45e4-4da7-aa9d-510dd7dd633a
# business profit 0
# business profit 0
# business profit 0
# business profit 22230000
# business profit 0
# business profit 7280000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 1220000
# business profit 0
# business profit 0
# business profit 2090000
# business profit 90000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 2130000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 80000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 1130000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# recording history; remaining agents: 741 tick: 1142
# in school 141
# sufficient skill to start business
# Starting a new business with id 78211933-17e6-4d13-bf5b-f00a6c7a8217
# sufficient skill to start business
# Starting a new business with id 3a5f0749-e824-4d4f-87cd-eafaa49448c6
# agent dropping out of school: 2f525a1f-4329-4e6c-a023-31846347012a
# agent dropping out of school: 12912830-77b3-46a2-bf19-0eb913455133
# agent dropping out of school: 4a265f2a-6c19-4769-9ea9-5879ad2d5c5e
# agent dropping out of school: 18193d7b-1ae9-490f-a69e-3a82dd679026
# agent dropping out of school: 0b2ae7ed-5c9e-4557-9868-7c7cb2246e89
# business profit 0
# business profit 0
# business profit 0
# business profit 22810000
# business profit 0
# business profit 7180000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 1260000
# business profit 0
# business profit 0
# business profit 2160000
# business profit 90000
# business profit 0
# Deleted business with id 446d985e-a142-4384-adf1-482602210eb6
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 2140000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 90000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 2240000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 70000
# Insufficient funds to pay base expenses 0430d420-3e96-4e74-a382-a9c5ea000617
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# recording history; remaining agents: 733 tick: 1143
# in school 147
# sufficient skill to start business
# Starting a new business with id 6c4b7937-e774-4945-97af-c00ddd34e7a4
# agent dropping out of school: 33cbc5f0-b815-4852-b430-99ace3c71e00
# agent dropping out of school: 50486857-8e81-4f12-86fa-63edeef4644d
# agent dropping out of school: 4569214f-0ad7-4a4d-8f6f-4e8145b817f6
# agent dropping out of school: d21d3daa-0757-4228-90a5-621e5fdce2fa
# business profit 0
# business profit 0
# business profit 23450000
# business profit 0
# business profit 6980000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 1270000
# business profit 0
# business profit 0
# business profit 2230000
# business profit 90000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 1800000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 100000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 3270000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 120000
# business profit 0
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# recording history; remaining agents: 730 tick: 1144
# in school 154
# sufficient skill to start business
# Starting a new business with id 0eab9f90-9d62-4fa3-9dce-e658d6ac318e
# sufficient skill to start business
# Starting a new business with id 36b9c3c7-4f40-477d-8110-b129b0a609c3
# agent dropping out of school: 9df894d8-58b3-401e-8dbc-c058f12c44a4
# agent dropping out of school: 7cc16bd9-21dc-4ac9-b130-e8de485fbf8a
# agent dropping out of school: d9c5bc12-b975-4c7b-9c65-740874d7cdd8
# agent dropping out of school: 718d43d9-edbb-42eb-9c76-38dfaf5c4d4e
# agent dropping out of school: 8edfef6c-4abf-4936-aeac-66d990cd1458
# agent dropping out of school: 15000df4-2f31-4d91-9057-b51fa12e5c73
# agent dropping out of school: 0ff4383e-b7f4-4d8f-8c13-cbe32c0ba405
# agent dropping out of school: 31c535ad-a00b-400e-a3f0-51d80d15bd0e
# business profit 0
# business profit 0
# Deleted business with id e823bef7-a091-4b3c-95de-16af5609d349
# business profit 23720000
# business profit 0
# Deleted business with id 54113cf3-8278-457e-a846-a886fdfec5f2
# business profit 6780000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 1300000
# business profit 0
# business profit 0
# business profit 2300000
# business profit 90000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 1810000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 110000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 4220000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 180000
# business profit 0
# business profit 0
# business profit 0
# Insufficient funds to pay base expenses 4247c7e0-58a3-46e6-874f-4a6bd6439ed8
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# recording history; remaining agents: 734 tick: 1145
# in school 168
# sufficient skill to start business
# Starting a new business with id e491b905-3f76-4fee-9e50-c4d5dbef9632
# sufficient skill to start business
# Starting a new business with id a57e5fd7-60a5-47ab-ba10-0e87d743abb8
# sufficient skill to start business
# Starting a new business with id c37f74f8-36eb-4549-b354-d4f7f4658743
# sufficient skill to start business
# Starting a new business with id 8a785ea3-05e7-40df-abc2-28d3ec1bec2d
# agent dropping out of school: ee83c75f-2be3-4fea-9d17-520774f39135
# agent dropping out of school: 23dfcd6c-757a-45ce-9a39-e75196cc4f46
# agent dropping out of school: afef0cb4-6787-409a-9dbe-b0554e711caf
# agent dropping out of school: 6728d511-fb2e-4482-b3ce-8fcb049d1e5e
# agent dropping out of school: 41e14367-a8c0-4dc2-afb6-f411ada9095b
# agent dropping out of school: 5a8c610c-271c-4a26-96e3-e73f6c9aadd0
# business profit 0
# business profit 24210000
# business profit 6670000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 1330000
# business profit 0
# business profit 0
# Deleted business with id 6ed73f7e-93c6-438d-90eb-36d34adc2e37
# business profit 2230000
# business profit 90000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 120000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 5060000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 250000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# Insufficient funds to pay base expenses 54f22e74-798a-47e7-a993-8732fb01fba0
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# recording history; remaining agents: 738 tick: 1146
# in school 93
# agent dropping out of school: 19d139c9-86d4-4507-914f-c4fef81a988f
# agent dropping out of school: 21772543-94e4-4e87-a28d-21e720e6cdfd
# agent dropping out of school: 3f84b7e6-80fc-43a7-a461-dafc33aaf948
# agent dropping out of school: d2cf79c5-0ef1-4ae6-9b52-acfdabbe4fa4
# business profit 0
# business profit 24650000
# business profit 6670000
# business profit 0
# Deleted business with id f68d9c99-34ca-4cb6-a887-b0714d7e5cf5
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 1360000
# business profit 0
# business profit 2300000
# business profit 90000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 130000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 20000
# business profit 6050000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 320000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# Insufficient funds to pay base expenses dbe32fc5-dc5f-4885-aaf9-6e8d5098a772
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# ...
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 370000
# business profit 0
# business profit 0
# business profit 7650000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# recording history; remaining agents: 755 tick: 1169
# in school 126
# sufficient skill to start business
# Starting a new business with id 4f5cd24e-1330-41bc-bdd5-c78652dc6960
# agent dropping out of school: db3d30f0-58a4-49b3-931a-eeb383a62cb6
# agent dropping out of school: 7ae42dd6-6b47-405e-875c-97c15137f86c
# agent dropping out of school: 530e049d-16e4-45ce-a000-082b371b7465
# agent dropping out of school: 9a2c0e46-cc76-4f61-a2b9-4fdac4ee7d7b
# agent dropping out of school: 8d9cb94d-6db2-47e9-976a-f0482ce8b7b2
# agent dropping out of school: 17bac9fe-f1fb-40e9-a743-84554256f6a8
# agent dropping out of school: 7cb691ef-e3b7-4a45-a955-8d84100217b4
# agent dropping out of school: 7679d96c-e566-49f6-99ff-f7ea388db79a
# business profit 0
# business profit 34520000
# business profit 4070000
# business profit 0
# Deleted business with id 075456d8-e4dd-4173-a65c-4ec5d423ddbf
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 2060000
# business profit 350000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 280000
# business profit 17700000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 8750000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# recording history; remaining agents: 755 tick: 1170
# in school 82
# sufficient skill to start business
# Starting a new business with id 560db504-a9fe-4491-8091-cb348fb67d2e
# agent dropping out of school: 21b20924-9515-4270-986f-5537c0229f1b
# agent dropping out of school: 5a5c39d7-86ae-4639-8790-5ac0fb24d208
# agent dropping out of school: 1de8b3e4-f785-433d-ac87-b5a870caad1f
# agent dropping out of school: 377b68c9-4e9f-4a1a-ad99-5b743c603e1e
# agent dropping out of school: 6df36507-106d-4027-9a98-c64f1e14b1d2
# agent dropping out of school: 564dc5b1-e26d-4294-9242-3abfb133bf7e
# agent dropping out of school: 1347f11c-1d1d-4e67-92dc-13e5fdc7017b
# agent dropping out of school: 81ecfa23-51f6-4487-b9d1-744a4c35919e
# agent dropping out of school: 99439679-62d7-4802-8def-268d9b8cf368
# agent dropping out of school: 8ac37cbf-0fa7-4508-9913-1e42c9017931
# business profit 0
# business profit 34690000
# business profit 4070000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 2100000
# business profit 380000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 300000
# business profit 17660000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 10110000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# recording history; remaining agents: 761 tick: 1171
# in school 96
# sufficient skill to start business
# Starting a new business with id be59a66d-be4e-40e0-ba83-638d5b61436d
# sufficient skill to start business
# Starting a new business with id 8aabf068-f38b-492a-bb64-4990873f0e9c
# agent dropping out of school: c2b5bebf-a46e-4038-9a55-c14d7f2082b3
# agent dropping out of school: 0fc8af74-97d4-499c-9c8a-9efc9f3aa80b
# business profit 0
# business profit 34000000
# business profit 3970000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 1520000
# business profit 180000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# Deleted business with id 899b4fad-5bf3-4542-ba76-884ecad6bfac
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 320000
# business profit 17000000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 11290000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# Insufficient funds to pay base expenses d8c73035-11ac-4d0e-8792-3bd3dbc02767
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# recording history; remaining agents: 761 tick: 1172
# in school 103
# agent dropping out of school: 32bd8c09-c4d9-4b0a-b8fa-5b4a0025990c
# agent dropping out of school: cd89d8ae-e59f-4a33-a279-4388e8e07011
# agent dropping out of school: 1d8fe78a-f8b2-425d-9800-a2cfb3af87de
# agent dropping out of school: 35e8bff0-967d-42ac-87aa-1eed424ba89c
# agent dropping out of school: a287a482-0d94-4674-bcc9-3dc1368c7e26
# agent dropping out of school: b2bf9181-94f8-4ba4-9bea-c97bdcc0c187
# agent dropping out of school: 229aec1e-1f0c-4c56-8496-bf6d3e0ef455
# agent dropping out of school: b16a1e99-bb2c-48cd-82a1-0a3ee1651ec4
# business profit 0
# business profit 34050000
# business profit 3970000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 1410000
# business profit 210000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 340000
# business profit 16660000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 12520000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# Deleted business with id 32e740c2-953d-4518-9f3c-e01ebe4c6158
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# Insufficient funds to pay base expenses 5eb523ae-9879-4ca5-baf8-9f69e8fea362
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# recording history; remaining agents: 757 tick: 1173
# in school 109
# sufficient skill to start business
# Starting a new business with id 5a10381d-d579-433b-bc4a-55b35351a6a8
# agent dropping out of school: bf557dc8-2aab-43e5-a467-705e1cf57147
# agent dropping out of school: aec7fa36-f279-4cbf-a0be-8d40191f7925
# agent dropping out of school: 49bba3f7-793f-43db-9cc7-795bc05faed2
# agent dropping out of school: e7a9b01c-221a-472f-923a-a9cee58246e8
# agent dropping out of school: 47772ce1-079c-4250-99a9-d4b44c412b07
# agent dropping out of school: 39a63f7f-52dd-4c66-b898-8835348be6f4
# agent dropping out of school: 3b706456-405b-4074-a876-7a975679539d
# business profit 0
# business profit 34150000
# business profit 3970000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 1440000
# business profit 240000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 360000
# business profit 16660000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 13880000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# recording history; remaining agents: 760 tick: 1174
# in school 121
# sufficient skill to start business
# Starting a new business with id 8da712b6-b415-4b8d-addd-2b7146a2a85d
# agent dropping out of school: 71945280-9d56-4199-a4d4-d4834f94b2ea
# agent dropping out of school: e44996ef-c033-42e7-b25a-1f02c6f64102
# agent dropping out of school: a4076a78-59bd-483d-97d3-92045f3d1a74
# agent dropping out of school: 9e63a56b-0c35-4832-a33d-7013d7d0cdb2
# agent dropping out of school: 2e46adff-e8c0-4cd4-a03a-94ca18f2fc02
# agent dropping out of school: e92001b2-cf06-4a43-a912-7bfa10f0fd97
# agent dropping out of school: a44656c9-15fb-472f-a66b-cf02afd94848
# agent dropping out of school: 19e0874c-9609-40d8-b38a-11991d2acabb
# agent dropping out of school: f2f55c18-2fce-4046-8edd-4f1f189770c2
# agent dropping out of school: 808670e4-f322-4b8d-b74f-2a9e8362137b
# agent dropping out of school: d4a31ac6-ccf8-4987-9913-107498cd737c
# agent dropping out of school: 49114038-4215-48a9-98a4-34d969991fc5
# agent dropping out of school: d403b217-cb0e-4eca-94e0-4059e177df8d
# business profit 0
# business profit 33930000
# business profit 3870000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 1470000
# business profit 270000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 380000
# business profit 16440000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 15260000
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# business profit 0
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# Created child
# recording history; remaining agents: 763 tick: 1175
# in school 133
# sufficient skill to start business
# Starting a new business with id d9cc682e-3dac-4b64-abaf-5d82c42330fc
# sufficient skill to start business
# Starting a new business with id 15a0ed92-b86b-4e81-8f5d-077d4bffbf4f
# sufficient skill to start business
# Starting a new business with id c824a9ca-98cf-41b7-9086-fdfc0b1597e1
# sufficient skill to start business
# Starting a new business with id 8a967e91-d2f9-41b5-be57-3febc7efaa28
